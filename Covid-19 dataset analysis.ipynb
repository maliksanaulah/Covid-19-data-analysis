# %%
import pandas as pd

# %%
data=pd.read_csv("covid_19_data.csv")

# %%
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %% [markdown]
# ## Explore the Data

# %%
data.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %% [markdown]
# ## Q.1) Show the number of comfirmed,Death and recovered cases in each Region.

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %% [markdown]
# ## Q.2) Show me top 5 highest Death rates Region?

# %%
top_5 = data.nlargest(5,"Deaths")
print(top_5[['Region','Deaths']])
# Out:
#      Region  Deaths
# 80    Italy   27682
# 168      UK   26097
# 153   Spain   24275
# 57   France   24087
# 265      US   23477

# %%
data.groupby('Region').agg({
    'Confirmed': 'sum',
    'Deaths': 'sum',
    'Recovered': 'sum'
})
# Out:
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# West Bank and Gaza        344       2         71
# Western Sahara              6       0          5
# Yemen                       6       0          1
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [187 rows x 3 columns]

# %% [markdown]
# ## Q.3) Combine Region and states Column

# %%
data["State"].fillna('No State',inplace=True)
data["rs"]=data["Region"] + "_" + data["State"]
data.head(59)
# Out:
#          Date     State                    Region  Confirmed  Deaths  \
# 0   4/29/2020  No State               Afghanistan       1939      60
# 1   4/29/2020  No State                   Albania        766      30
# 2   4/29/2020  No State                   Algeria       3848     444
# 3   4/29/2020  No State                   Andorra        743      42
# 4   4/29/2020  No State                    Angola         27       2
# 5   4/29/2020  No State       Antigua and Barbuda         24       3
# 6   4/29/2020  No State                 Argentina       4285     214
# 7   4/29/2020  No State                   Armenia       1932      30
# 8   4/29/2020  No State                   Austria      15402     580
# 9   4/29/2020  No State                Azerbaijan       1766      23
# 10  4/29/2020  No State                   Bahamas         80      11
# 11  4/29/2020  No State                   Bahrain       2921       8
# 12  4/29/2020  No State                Bangladesh       7103     163
# ...

# %% [markdown]
# ## Q.4) Show me the countries which have zero Death rate?

# %%
data[data["Deaths"]==0][["rs","Deaths"]]
# Out:
#                                                rs  Deaths
# 18                                Bhutan_No State       0
# 29                              Cambodia_No State       0
# 31              Central African Republic_No State       0
# 45                              Dominica_No State       0
# 51                               Eritrea_No State       0
# 55                                  Fiji_No State       0
# 64                               Grenada_No State       0
# 70                              Holy See_No State       0
# 90                                  Laos_No State       0
# 99                            Madagascar_No State       0
# 110                             Mongolia_No State       0
# 113                           Mozambique_No State       0
# 114                              Namibia_No State       0
# 115                                Nepal_No State       0
# 126                     Papua New Guinea_No State       0
# ...

# %% [markdown]
# ## Q.5) How many Regions which have zero Death rate?

# %%
data.head(2)
# Out:
#         Date     State       Region  Confirmed  Deaths  Recovered  \
# 0  4/29/2020  No State  Afghanistan       1939      60        252
# 1  4/29/2020  No State      Albania        766      30        455
#
#                      rs
# 0  Afghanistan_No State
# 1      Albania_No State

# %%
death=data.loc[data["Deaths"]==0]["Region"].nunique()
print("No of regions with zero Deaths=",death)
# Out:
# No of regions with zero Deaths= 36

# %%
data_Copy=data.copy()
data_Copy["Region"].replace("Afghan","Afghansitan",inplace=True)
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered  \
# 0    4/29/2020  No State     Afghanistan       1939      60        252
# 1    4/29/2020  No State         Albania        766      30        455
# 2    4/29/2020  No State         Algeria       3848     444       1702
# 3    4/29/2020  No State         Andorra        743      42        423
# 4    4/29/2020  No State          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
#                           rs
# 0       Afghanistan_No State
# 1           Albania_No State
# ...

# %% [markdown]
# ## Q.6) Top 5 rs(Resion_states) which have high recovered cases?

# %%
data.head(2)
# Out:
#         Date     State       Region  Confirmed  Deaths  Recovered  \
# 0  4/29/2020  No State  Afghanistan       1939      60        252
# 1  4/29/2020  No State      Albania        766      30        455
#
#                      rs
# 0  Afghanistan_No State
# 1      Albania_No State

# %%
top5=data.nlargest(5,'Recovered')
print(top5[['rs','Recovered']])
# Out:
#                    rs  Recovered
# 153    Spain_No State     132929
# 285      US_Recovered     120720
# 61   Germany_No State     120400
# 76      Iran_No State      73791
# 80     Italy_No State      71252

# %% [markdown]
# ## Q.7)Regions which have 0 recovered cases?

# %%
a=data[data['Recovered']==0][['rs','Recovered']]
a
# Out:
#                             rs  Recovered
# 98         MS Zaandam_No State          0
# 116       Netherlands_No State          0
# 126  Papua New Guinea_No State          0
# 152       South Sudan_No State          0
# 168                UK_No State          0
# ..                         ...        ...
# 312              US_Washington          0
# 313           US_West Virginia          0
# 315               US_Wisconsin          0
# 316                 US_Wyoming          0
# 318               Canada_Yukon          0
#
# [78 rows x 2 columns]

# %% [markdown]
# ## Q.8)total number of regions which have 0 recovered cases?

# %%
print("Total region with zero Recovered cases=",len(a))
# Out:
# Total region with zero Recovered cases= 78

# %%
data.head(2)
# Out:
#         Date     State       Region  Confirmed  Deaths  Recovered  \
# 0  4/29/2020  No State  Afghanistan       1939      60        252
# 1  4/29/2020  No State      Albania        766      30        455
#
#                      rs
# 0  Afghanistan_No State
# 1      Albania_No State

# %% [markdown]
# ## Q.9) top 5 regions which have highest confirmed cases?

# %%
t5=data.nlargest(5,"Confirmed")
print(t5[["rs","Confirmed"]])
# Out:
#                   rs  Confirmed
# 265      US_New York     299691
# 153   Spain_No State     236899
# 80    Italy_No State     203591
# 168      UK_No State     165221
# 57   France_No State     165093

# %% [markdown]
# ## Q.10) Which regoin have least cases top least 5 regions?

# %%
l5=data.nsmallest(5,"Confirmed")
print(l5[["rs","Confirmed"]])
# Out:
#                                       rs  Confirmed
# 203  Canada_Diamond Princess cruise ship          0
# 284                     Canada_Recovered          0
# 285                         US_Recovered          0
# 289     France_Saint Pierre and Miquelon          1
# 305                 Mainland China_Tibet          1

# %% [markdown]
# ## Q.11) Removed all the records where Confirmed cases is less than 10?

# %%
data[~(data.Confirmed <10)]
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered  \
# 0    4/29/2020  No State     Afghanistan       1939      60        252
# 1    4/29/2020  No State         Albania        766      30        455
# 2    4/29/2020  No State         Algeria       3848     444       1702
# 3    4/29/2020  No State         Andorra        743      42        423
# 4    4/29/2020  No State          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
#                           rs
# 0       Afghanistan_No State
# 1           Albania_No State
# ...

# %% [markdown]
# ## Q.12) How many Confirmed ,deaths and Recovered cases were reported from US till 29 April 2020?

# %%
s=data.loc[(data["Region"]=="US") & (data["Date"]<="4/29/2020")]
s
# Out:
#           Date                         State Region  Confirmed  Deaths  \
# 181  4/29/2020                       Alabama     US       6912     256
# 182  4/29/2020                        Alaska     US        355       9
# 186  4/29/2020                       Arizona     US       7209     308
# 187  4/29/2020                      Arkansas     US       3193      57
# 195  4/29/2020                    California     US      48747    1946
# 199  4/29/2020                      Colorado     US      14758     766
# 200  4/29/2020                   Connecticut     US      26767    2169
# 202  4/29/2020                      Delaware     US       4655     144
# 204  4/29/2020  Diamond Princess cruise ship     US         49       0
# 205  4/29/2020          District of Columbia     US       4106     205
# 208  4/29/2020                       Florida     US      33193    1218
# 213  4/29/2020                       Georgia     US      25775    1101
# ...

# %%
len(s)
# Out:
# 58

# %% [markdown]
# ## Q.13) Sort ths data wrt Confirmed  cases in ascending order?

# %%
data.sort_values(by=["Confirmed"],ascending=True)
# Out:
#           Date                         State          Region  Confirmed  \
# 285  4/29/2020                     Recovered              US          0
# 284  4/29/2020                     Recovered          Canada          0
# 203  4/29/2020  Diamond Princess cruise ship          Canada          0
# 305  4/29/2020                         Tibet  Mainland China          1
# 289  4/29/2020     Saint Pierre and Miquelon          France          1
# ..         ...                           ...             ...        ...
# 57   4/29/2020                      No State          France     165093
# 168  4/29/2020                      No State              UK     165221
# 80   4/29/2020                      No State           Italy     203591
# 153  4/29/2020                      No State           Spain     236899
# 265  4/29/2020                      New York              US     299691
#
#      Deaths  Recovered                                   rs
# ...
